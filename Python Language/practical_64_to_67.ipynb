# %%
# 64---. A python program that helps to know the effects of slicing operations on an array. 

import array as a 
l1 = [1,2,3,4,5]
a1 = a.array('i', l1)
print(a1)
print(a1[1:3])
print(a1[:5])
print(a1[2:])
print(a1[-3:])
print(a1[-4:-1])
print(a1[0::2])
# Out:
# array('i', [1, 2, 3, 4, 5])
# array('i', [2, 3])
# array('i', [1, 2, 3, 4, 5])
# array('i', [3, 4, 5])
# array('i', [3, 4, 5])
# array('i', [2, 3, 4])
# array('i', [1, 3, 5])

# %%
# 65---> A python program to sort the array elements using bubble sort technique
import array as a
n = int(input("Enter number of elements in array :"))
l1 = [int(x) for x in input("Enter array  : ").split()]
myArray = a.array('i',l1)
print(l1)
for i in range(n):
        for j in range(n-1-i):
            if myArray[j] > myArray[j+1]:
                temp = myArray[j]
                myArray[j] = myArray[j+1]
                myArray[j+1] = temp
print("Array after sorting is :", myArray)
# Out:
# [100, 50, 75, 25, 10]
# Array after sorting is : array('i', [10, 25, 50, 75, 100])

# %%
# 66--->  A python program to search for the position of an element in an array using index () method. 

import array as a
l1 = [int(x) for x in input("Enter array  : ").split()]
myArray = a.array('i',l1)
print(myArray)
n = int(input("Enter position :"))
print("The value is", l1.index(n))
# Out:
# array('i', [5, 10, 15, 25, 2])
# The value is 4

# %%
# 67 --->  A python program to accept two matrices and find their product. 

import numpy as np
print("Enter number of rows and columns for matrix 1 :")
row1,col1 = [int(x) for x in input("\n").split()]
print("Enter number of rows and columns for matrix 2 :")
row2,col2 = [int(x) for x in input("\n").split()]

if col1 != row2:
    print("Matrix multiplication is not possible !")
else:
    str1 = [int(x) for x in input("Enter elements for matrix 1: ").split()]
    str2 = [int(x) for x in input("Enter elements for matrix 2: ").split()]
mat1 = np.reshape(np.matrix(str1), (row1,col1))
mat2 = np.reshape(np.matrix(str2), (row2,col2))
matprod = mat1*mat2
print("Given matrices are : \n", mat1, mat2)
print("Product is : \n", matprod)
# Out:
# Enter number of rows and columns for matrix 1 :
#
# 2 2
# Enter number of rows and columns for matrix 2 :
#
# 2 2
# Enter elements for matrix 1: 1 0 0 1
# Enter elements for matrix 2: 1 0 0 1
# Given matrices are :
#  [[1 0]
#  [0 1]] [[1 0]
#  [0 1]]
# Product is :
#  [[1 0]
#  [0 1]]
